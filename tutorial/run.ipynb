# %%
cd ..

# %% [markdown]
# *You have to run the whole pipeline as below at first.*

# %%
sbt "run-main uima.cpe.CPERunner"
# Out:
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option MaxPermSize=384m; support was removed in 8.0
# [info] Loading project definition from /Users/sakamoto/Documents/FelisCatusZero/project
# [info] Set current project to FelisCatusZero (in build file:/Users/sakamoto/Documents/FelisCatusZero/)
# [info] Running uima.cpe.CPERunner
# [info] >> CPE Processing
# [info] >> Question Analyzer Initializing
# [info] >> Gzipped XMI Cas Consumer Initializing
# [info] output CAS as Gzipped XMI into out/xmi/qa
# [info] >> Information Retriever Initializing
# [info] >> Gzipped XMI Cas Consumer Initializing
# [info] output CAS as Gzipped XMI into out/xmi/ir
# [info] >> Essay Generator Initializing
# [info] >> Essay Writer Initializing
# [info] >> Gzipped XMI Cas Consumer Initializing
# [info] output CAS as Gzipped XMI into out/xmi/eg
# [info] >> Essay Evaluator Initializing
# [info] >> Essay Question Reader Initializing
# [info] CPM Initialization Complete
# ...

# %% [markdown]
# *out/result/2017-01-25T15:00:11.826+09:00/evaluation_result.html is automatically opened by the default web browswer.*
# <img src="image/evaluation_result_whole_pipeline.png"/>

# %% [markdown]
# *If the "HISTORY" link in the above page is clicked, out/result/index.html is shown as below.*
# <img src="image/evaluation_result_history_first_time.png"/>

# %% [markdown]
# *If you want to run the pipeline from Essay Generator, do as below.*

# %%
sbt "run-main uima.cpe.CPERunner -from eg"
# Out:
# Java HotSpot(TM) 64-Bit Server VM warning: ignoring option MaxPermSize=384m; support was removed in 8.0
# [info] Loading project definition from /Users/sakamoto/Documents/FelisCatusZero/project
# [info] Set current project to FelisCatusZero (in build file:/Users/sakamoto/Documents/FelisCatusZero/)
# [info] Running uima.cpe.CPERunner -from eg
# [info] >> CPE Processing
# [info] >> Question Analyzer Initializing
# [info] >> Gzipped XMI Cas Consumer Initializing
# [info] output CAS as Gzipped XMI into out/xmi/qa
# [info] >> Information Retriever Initializing
# [info] >> Gzipped XMI Cas Consumer Initializing
# [info] output CAS as Gzipped XMI into out/xmi/ir
# [info] >> Essay Generator Initializing
# [info] >> Essay Writer Initializing
# [info] >> Gzipped XMI Cas Consumer Initializing
# [info] output CAS as Gzipped XMI into out/xmi/eg
# [info] >> Essay Evaluator Initializing
# [info] >> Gzipped XMI Collection Reader Initializing
# [info] input CAS from Gzipped XMI out/xmi/qa/0.xmi.gz
# ...

# %% [markdown]
# *out/result/2017-01-25T15:12:53.784+09:00/evaluation_result.html is automatically opened by the default web browswer.*
# <img src="image/evaluation_result_part_pipeline.png"/>

# %% [markdown]
# *If the HISTORY link in the above page is clicked, out/result/index.html is shown as below.*
# <img src="image/evaluation_result_history_second_time.png"/>
